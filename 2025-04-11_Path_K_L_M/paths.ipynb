# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import datetime
import scipy.stats
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.dates as mdates

# %%
data = pd.read_excel("memo_data.xlsx")
data.columns = ['Run', 'Identifier', 'Mass', 'Amp44', 'Area44', 'd13C', 'd18O']
data["Identifier"] = data["Identifier"].str.replace("SPL A4 Path ","").str.replace("SPL A  Path ","")
data[["Path","SampleNr"]] = data["Identifier"].str.split(" ", expand=True)
data
# Out:
#      Run Identifier   Mass  Amp44  Area44  d13C  d18O Path SampleNr
# 0     13       K 1A  0.215  10719     135  -1.0  25.7    K       1A
# 1     14       K 2A  0.300  17651     210  -0.9  25.8    K       2A
# 2     15       K 3A  0.275  14974     186  -1.1  25.5    K       3A
# 3     16       K 4A  0.207  12308     152  -1.1  25.6    K       4A
# 4     17       K 5A  0.240  12764     155  -0.7  25.5    K       5A
# ..   ...        ...    ...    ...     ...   ...   ...  ...      ...
# 140  187      M 22A  0.122   6033      73  -1.5  25.9    M      22A
# 141  188      M 23A  0.322  17960     224  -1.3  25.6    M      23A
# 142  189      M 24A  0.264  14865     183  -1.5  25.8    M      24A
# 143  190      M 25A  0.320  14019     170  -1.0  25.6    M      25A
# 144  191      M 26A  0.276  14999     187  -1.2  25.6    M      26A
#
# [145 rows x 9 columns]

# %%
data["Sample"]
# Out:
# 0       1A
# 1       2A
# 2       3A
# 3       4A
# 4       5A
#       ...
# 140    22A
# 141    23A
# 142    24A
# 143    25A
# 144    26A
# Name: Sample, Length: 145, dtype: object
