# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import datetime
import scipy.stats
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.colors as cl
import matplotlib.dates as mdates
import matplotlib
import statsmodels.api as sm
from statsmodels.regression.rolling import RollingOLS
import seaborn as sns
from scipy.optimize import curve_fit

# %%
haw_data = pd.read_csv('test_lauren/MHHW.csv', header=None)
haw_data.rename(columns={0:'Year',1:'Month',2:'Days',3:'MHHW'}, inplace=True)
haw_data['decimal_year'] = haw_data['Year'] + haw_data['Month']/12
haw_data

# %%
fred = pd.read_excel('test_lauren/Honiara_TideGauge.xlsx')
fred

# %%
fig, ax = plt.subplots(1, figsize=(8,5))

ax.plot(haw_data['decimal_year'], haw_data['MHHW'], '.')
ax.set_ylim(300,1000)
ax2= ax.twinx()
ax2.plot(fred['Year'], fred['Sea Level from Tide Gauge Honiara (cm)'], '.', color='red')
