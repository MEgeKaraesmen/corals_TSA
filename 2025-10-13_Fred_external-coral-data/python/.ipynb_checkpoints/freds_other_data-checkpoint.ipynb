# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import datetime
import scipy.stats
#import plotly.offline as pyo
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.colors as cl
import matplotlib.dates as mdates
import matplotlib
import statsmodels.api as sm
from statsmodels.regression.rolling import RollingOLS
import seaborn as sns
import netCDF4 as nc
import xarray as xr
#import cartopy.crs as ccrs
#from cartopy import feature as cfa
import os
import plotly.io as pio
pio.renderers.default = 'notebook'

# %%
Naru = pd.read_excel('../memo_edited.xlsx', sheet_name='Naru')
Gizo = pd.read_excel('../memo_edited.xlsx', sheet_name='Gizo')
Gizo['age'] = Gizo['age'].str.replace(' year','').str.replace('m','').astype(int)
Gizo.sort_values('age', inplace=True)

window_size=6
Gizo[['age_ma','d13c_ma','d18o_ma']] = Gizo.rolling(window_size).mean()
Gizo

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=Gizo['age'], y=Gizo['d13C'] , mode="light green", line_color='#05700C', name='Gizo'), secondary_y=False)
fig.add_trace(go.Scatter(x=Gizo['age_ma'], y=Gizo['d13c_ma'] , mode="lines", line_color='#05700C', name='Gizo'), secondary_y=False)
